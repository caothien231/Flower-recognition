# %% [markdown]
# There are thousands type of
# ower in the word. They can be very
# di
# erent and also very similar. Due to the complexity to recognize flowers, the traditional way by comparing the
# ower features may very
# dicult and time consuming to distinguish
# owers. With the power
# of machine learning, we can solve this problem with a very low rate of
# failure to recognize
# owers. Flower recognition is an multi-class classi-
#
# cation problem. There are 5 di
# erent types of image
# owers(classes):
# Daisy, Dandelion, Rose, Sun
# ower, and Tulip. The whole data set
# contains 4242 images of
# owers. Each class has 800 photos, and each
# photo has di
# erent sizes and resolutions. Because of the di
# erence in
# size and resolution, we may need to do some feature engineering to
# bring all the images to the same size. Then using the data set to train
# a neural network model to recognize
# ower images. The outcome is
# a model that can recognize
# ower images correctly on the new date
# with a high accuracy.

# %% [markdown]
# # New Section

# %%
#import library
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os
import matplotlib.pyplot as plt
import pydot
from skimage import io
import numpy as np
import seaborn as sns

# %% [markdown]
# I get this dataset from https://www.kaggle.com/datasets/alxmamaev/flowers-recognition/download?datasetVersionNumber=2
# this dataset is a collection of 4242 flower images belong to 5 classes(chamomile, tulip, rose, sunflower, dandelion).
# The dataset is divided into 2 diferent folders-trainiing and test. Each training and test folder cantains 5 different folders that contains the flower images for each classes.
# So to load the data from these folders, i use image_dataset_from_directory() from keras. It will return a dataset object that contains all the images of in that subdirectory with the labels corecponding for that class.

# %%
#1 load dataset
image_size = (180, 180)
batch_size = 32
classes = ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/input_data/flowers/training",
    labels='inferred',
    label_mode='categorical',
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=image_size,
    batch_size=batch_size,
    class_names=classes,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/input_data/flowers/training",
    labels='inferred',
    label_mode='categorical',
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=image_size,
    batch_size=batch_size,
    class_names=classes,
)
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/input_data/flowers/test",
    #validation_split=0,
    #subset="validation",
    labels='inferred',
    label_mode='categorical',
    seed=42,
    image_size=image_size,
    batch_size=1,
    class_names=classes,
)
# Out:
# Found 3456 files belonging to 5 classes.
# Using 2765 files for training.
# Found 3456 files belonging to 5 classes.
# Using 691 files for validation.
# Found 861 files belonging to 5 classes.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        #plt.title(int(labels[i]))
        plt.axis("off")

# %% [markdown]
# Data Argumentation is way to processiong the data before use it to train the model. When we apply data argumentation on the images. From the the original images, we can have multiple version of them by shifting, rotating, and resizing them.
# The model that i will use is base on CNN (convolutional neural network) architechture. And CNN is work the best if we can give the model a good amount of data. So by aplly the data argementation, i can increasing the number of images to train the model.
# Second reason for using data argumentation is the model need to lear the object (image) in any condition. For example, if all the rose images in the dataset have the rose place on the right-top of the images. After training the model using this dataset. I test with a sunflower image that the sunflower also place at the right-top of the image. There is a high chance that this model will make a wrong prediction. Cause it learn from the training data that the object palce at the right-top mostly is rose. BY aplly data argumentation, we can improve the relevant data in the dataset.
# I create layer that aplly the rotation and flip on each image. This layers will get involve when i build the model.

# %%
data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(0.1),
    ]
)
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# The Model that i use is call Xception. This model is base on CNN architechture. However, there are some diferences compare to the ordinary CNN model.
# 1. Deepwise Seperatable Convolution
# this can be the main thing that make the Xception different than the CNN. For the normall CNN, Convolution is a really expensive operation.
# For a color image, we need to use c channels. we apply the convolution filter of size d*d on the dimention A. If for N Kernel, the number of operations is
#  A^2 x d^2 x c x N
#  So the Deepwise Seperatable Convolution is introduced to reduce the number of operations. Also reducing the number of parameter that hte model need. BY that it reduce the overfitting that usually see on CNN model.
# 2. Shortcut between Convulution blocks
#  As we already learn this from Resnet model, this shortcut is a way to reduce the degradation problem. It allows us to build a deeper model.

# %%
train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Image augmentation block
    x = data_augmentation(inputs)

    # Entry block
    x = layers.experimental.preprocessing.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [128, 256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)


model = make_model(input_shape=image_size + (3,), num_classes=5)
keras.utils.plot_model(model, show_shapes=True)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 180, 180, 3)  0           ['input_1[0][0]']
#
#  rescaling (Rescaling)          (None, 180, 180, 3)  0           ['sequential[0][0]']
#
#  conv2d (Conv2D)                (None, 90, 90, 32)   896         ['rescaling[0][0]']
#
#  batch_normalization (BatchNorm  (None, 90, 90, 32)  128         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 90, 90, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 90, 90, 64)   18496       ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 90, 90, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
# ...

# %% [markdown]
# For training the model is use Adam optimizer with 50 epoches.

# %%
epochs = 50

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
)
# Out:
# Epoch 1/50
# 87/87 [==============================] - 417s 5s/step - loss: 0.4048 - accuracy: 0.5559 - val_loss: 0.5757 - val_accuracy: 0.2590
# Epoch 2/50
# 87/87 [==============================] - 26s 296ms/step - loss: 0.3254 - accuracy: 0.6488 - val_loss: 0.6384 - val_accuracy: 0.2590
# Epoch 3/50
# 87/87 [==============================] - 25s 288ms/step - loss: 0.2922 - accuracy: 0.6792 - val_loss: 0.8930 - val_accuracy: 0.2590
# Epoch 4/50
# 87/87 [==============================] - 25s 288ms/step - loss: 0.2841 - accuracy: 0.6998 - val_loss: 0.9657 - val_accuracy: 0.2590
# Epoch 5/50
# 87/87 [==============================] - 25s 287ms/step - loss: 0.2650 - accuracy: 0.7150 - val_loss: 1.1918 - val_accuracy: 0.2590
# Epoch 6/50
# 87/87 [==============================] - 26s 290ms/step - loss: 0.2506 - accuracy: 0.7400 - val_loss: 0.5312 - val_accuracy: 0.3980
# Epoch 7/50
# ...

# %% [markdown]
# Evaluation
# To evaluate the model, i will use 3 ways to to it.
# 1. Accuracy
# 2. Confustion matrix
# 3. Singlke testing image

# %% [markdown]
# For the accuracy, wiith 50 epoches, the model get the training accuracy about 96 % with the loss about 0.0402. This is a very good accuracy but we need to check if the model get overfitting or not (this is the problem that most of CNN model facing).
# So we need to evalute the model on the test dataset. So for the test dataset, the model gives the accuracy about 75 %. we can tell that the model get overfitting. The tesing accuracy is less than the traing accuracy wit about 10% gap between them.

# %%
scores = model.evaluate(test_ds)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 861/861 [==============================] - 123s 140ms/step - loss: 0.4175 - accuracy: 0.7340
# Accuracy: 73.40%

# %%
true_labels = []
predicted_labels = []
for x,y in test_ds:
    pred = model.predict(x)
    true_labels.append(np.where(y == 1)[1][0])
    predicted_labels.append(np.where(pred == np.amax(pred))[1][0])
# Out:
# ...
# 1/1 [==============================] - 0s 16ms/step

# %%
cm = tf.math.confusion_matrix(labels=true_labels, predictions=predicted_labels).numpy()
cm
# Out:
# array([[101,  22,  15,  12,   3],
#        [ 12, 177,   6,  12,   3],
#        [  4,   5, 126,   5,  16],
#        [  1,   8,   8, 129,   0],
#        [ 12,   7,  68,  10,  99]], dtype=int32)

# %% [markdown]
# Confustion matrix:
# The confustion matrix shows the number of correct and false predictions of the model. from it, i can tell that the model does well on dandelion and daisy classes. However, on the the rose and tuplip classes, it miss a lot predictions. Mostly it predicted tuplit as rose.

# %%
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='' , xticklabels = classes , yticklabels = classes)
plt.show()

# %% [markdown]
# Single Image testing:
# i pick a random image fro mthe test dataset and let the model predict it. Also i print out percentage of each classes are predicted by the model on the testing image.
# For this example, the model predict the testing image match 0.00 percent Daisy, 0.00 percent Dandelion 98.82 percent Rose, 0.04 percent Sunflower,1.14 percent Tulip.

# %%
img = keras.preprocessing.image.load_img(
    "/content/drive/MyDrive/input_data/flowers/test/sunflower/34692938506_efda47f39a_n.jpg", target_size=image_size
)
ax = plt.subplot(1, 1, 1)
plt.imshow(img)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
score = predictions[0]
score[0]
print(
    "This image is %.2f percent Daisy, %.2f percent Dandelion %.2f percent Rose, %.2f percent Sunflower,%.2f percent Tulip."
    % (100 * (score[0]), 100 * score[1],100 * score[2],100 * score[3],100 * score[4])
)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# This image is 0.01 percent Daisy, 0.03 percent Dandelion 76.30 percent Rose, 22.67 percent Sunflower,1.00 percent Tulip.

# %%
images = []
compare = []
for x,y in test_ds:
    images.append(x)
    compare.append(np.where(y == 1)[1][0])
sq = tf.squeeze(images)
index = 0
d = 0
while index < 3: 
    ax = plt.subplot(3, 3, index + 1)   
    img_array = sq[d].numpy().astype("uint8")
    prediction = model.predict(np.array([img_array]))
    prediction_name = classes[np.argmax(prediction)]
    real_name = classes[compare[d]]    
    if prediction_name != real_name:
        
        plt.title(f'real: {real_name}\npred:{prediction_name}', fontdict={'color': 'r'})
        plt.imshow(img_array)
        index = index + 1
        d = d + 1
        
    else:
        d = d + 1
    plt.axis("off")
# Out:
# ...
# 1/1 [==============================] - 0s 16ms/step
# <ipython-input-13-7a1414cbd769>:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(3, 3, index + 1)
# ...
# 1/1 [==============================] - 0s 17ms/step
